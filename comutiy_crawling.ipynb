# %% [markdown]
# # 주제
# 유명한 커뮤니티 게시글 제목 크롤링 및 유의미한 분석
#
# ### Spec
# - Python
# - Hadoop/Spark
#
# ### 1. 수집(데이터 전처리)
# - 유명한 커뮤니티 https://todaybeststory.com/community.html
# - SNS (인스타그램, 트위터, 페이스북)
#
# #### 1.1 수집 방식
# - 형태: 경험 로그, 비정형
# - 시간: 실시간 (추후에 배치)
#
# 1. RESTful API (반정형)
# 2. BeautySoup
#
#
# #### 1.2 데이터 수집 개수
# - 1만건 (대용량 데이터 처리)
#
# #### 1.3 수집 파이프라인 (TODO)
# - 데이터 파이프라인 시스템 설계
#
# #### 1.4 저장방식
# - 일단은 csv 로 저장 (추후에 NoSQL, 나아가 Hive 이용)
#
# ### 2. 정제
#
# #### 2.1. 데이터 스키마
# - UUID
# - 제목
# - 작성자
# - 상세 주소
# - 사이트 이름
# - 댓글 개수
# - 추천수 (1대1 갱신 가능하도록)
# - 조회수
#
#
# #### 2.2 가공
# - Identification
# 웨어하우스에서 데이터 읽어옴
#
# - Filtration
# 중복 처리
#
# - Validation
# TODO
#
# - Noise Reduction
# 스키마 만족 못하면 제거
#
# - Transformation
# 스키마 형태로 데이터 가공
#
# - Compression
# Base64 압축
#
# - Integration
# 처리 완료한 데이터를 적재
#
#
# ### 3. 적재
# - rdb, csv 는 별도 정제 필요 없음
# - NoSQL, RDB, 클라우드 스토리지, HDFS
#
# - 네이버, 쿠팡 구조 참고
# - Fast-api
#
#
# ### 4. 분석 & Machine Leaning
#
#
# ### 5. 시각화
# - matplotlib
#
#
# ### 구조
